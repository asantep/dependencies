# %%
import pandas as pd

# %%
p = '/home/local/USHERBROOKE/owup2301/Téléchargements/all_six_datasets/all_six_datasets/weather'
df = pd.read_csv(f'{p}/weather.csv', index_col=0)

# %%
df.shape
# Out:
# (52696, 21)

# %%
df.head()
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# date
# 2020-01-01 00:10:00   1008.89      0.71    273.18        -1.33    86.1
# 2020-01-01 00:20:00   1008.76      0.75    273.22        -1.44    85.2
# 2020-01-01 00:30:00   1008.66      0.73    273.21        -1.48    85.1
# 2020-01-01 00:40:00   1008.64      0.37    272.86        -1.64    86.3
# 2020-01-01 00:50:00   1008.61      0.33    272.82        -1.50    87.4
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# date
# 2020-01-01 00:10:00          6.43          5.54          0.89       3.42
# 2020-01-01 00:20:00          6.45          5.49          0.95       3.39
# 2020-01-01 00:30:00          6.44          5.48          0.96       3.39
# 2020-01-01 00:40:00          6.27          5.41          0.86       3.35
# 2020-01-01 00:50:00          6.26          5.47          0.79       3.38
#
#                      H2OC (mmol/mol)  ...  wv (m/s)  max. wv (m/s)  wd (deg)  \
# ...

# %%
df['OT']
# Out:
# date
# 2020-01-01 00:10:00    428.1
# 2020-01-01 00:20:00    428.0
# 2020-01-01 00:30:00    427.6
# 2020-01-01 00:40:00    430.0
# 2020-01-01 00:50:00    432.2
#                        ...
# 2020-12-31 23:20:00    433.0
# 2020-12-31 23:30:00    439.6
# 2020-12-31 23:40:00    435.2
# 2020-12-31 23:50:00    433.9
# 2021-01-01 00:00:00    436.5
# Name: OT, Length: 52696, dtype: float64
